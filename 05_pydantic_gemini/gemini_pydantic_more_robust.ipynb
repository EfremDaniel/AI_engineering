# %%
from google import genai
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="List a few asian soups recipes, a yummy description and list the ingredients"
)

print(response.text)
# Out:
# Here are a few delightful Asian soup recipes, complete with a yummy description and the key ingredients to get you started on your culinary journey!
#
# ---
#
# ### 1. Pho Bo (Vietnamese Beef Noodle Soup)
#
# **Yummy Description:** Imagine a warm, soulful embrace in a bowl! Pho Bo is Vietnam's iconic beef noodle soup, celebrated for its incredibly fragrant, deeply savory broth slow-simmered with star anise, cinnamon, and ginger. It's brimming with tender slices of beef, slippery rice noodles, and a vibrant medley of fresh herbs, lime, and chilies that you customize to perfection. Pure comfort and an explosion of clean, complex flavors.
#
# **Key Ingredients:**
# *   **Broth:** Beef bones (marrow, knuckle, oxtail), flank steak, onions, ginger, star anise, cinnamon sticks, cloves, cardamom pods, rock sugar, fish sauce.
# *   **Noodles:** Flat rice noodles (bánh phở).
# *   **Meat:** Thinly sliced raw beef (e.g., eye of round, sirloin) that cooks in the hot broth, pre-cooked brisket or flank steak.
# *   **Garnishes:** Bean sprouts, fresh basil, cilantro, green onions, lime wedges, jalapeño or bird's eye chili slices, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Tom Yum Goong (Thai Hot and Sour Shrimp Soup)
#
# **Yummy Description:** Get ready for a thrilling flavor ride! Tom Yum Goong is Thailand's famous hot and sour soup, a vibrant explosion of zesty lemongrass, fiery chilies, pungent galangal, and aromatic kaffir lime leaves. This intensely fragrant broth perfectly complements succulent shrimp and mushrooms, delivering a balance of spicy, sour, savory, and a hint of sweet that will awaken every single taste bud.
#
# **Key Ingredients:**
# *   **Broth Base:** Shrimp stock (or chicken stock/water), lemongrass stalks, galangal slices, kaffir lime leaves, Thai bird's eye chilies (fresh or dried), fish sauce, lime juice, roasted chili paste (nam prik pao - optional but recommended), evaporated milk or coconut milk (for creamy version).
# *   **Main Protein:** Medium to large shrimp (peeled and deveined).
# *   **Vegetables:** Straw mushrooms, oyster mushrooms, or shiitake mushrooms, cherry tomatoes.
# *   **Garnish:** Fresh cilantro leaves.
#
# ---
#
# ### 3. Shoyu Ramen (Japanese Soy Sauce Ramen)
#
# **Yummy Description:** Dive into a bowl of pure Japanese bliss! Shoyu Ramen features a deeply savory, umami-rich broth made with a soy sauce (shoyu) base, often balanced with chicken, pork, or dashi stock. It’s a harmonious symphony of chewy ramen noodles, melt-in-your-mouth slices of chashu pork, a perfectly soft-boiled egg, and a scattering of fresh toppings that make every slurp utterly satisfying.
#
# **Key Ingredients:**
# *   **Broth (Dashi/Stock):** Chicken or pork bones, water, kombu (dried kelp), katsuobushi (bonito flakes) for dashi, aromatics like ginger and garlic.
# *   **Tare (Flavoring Concentrate):** Soy sauce (shoyu), mirin, sake, a pinch of sugar, often a bit of dashi.
# *   **Noodles:** Fresh ramen noodles (alkaline noodles).
# *   **Toppings:** Chashu (braised pork belly or shoulder), Ajitama (marinated soft-boiled egg), Nori (seaweed sheets), Menma (fermented bamboo shoots), sliced green onions, narutomaki (fish cake - optional).
#
# ---
#
# ### 4. Wonton Soup (Chinese Comfort Soup)
#
# **Yummy Description:** A quintessential Chinese comfort food! Wonton soup offers a delightful interplay of delicate, silken wontons filled with seasoned pork and shrimp, floating in a light yet deeply savory clear chicken or pork broth. It's a bowl of soothing warmth, often garnished simply with fresh greens and a sprinkle of scallions, making it perfect for a cozy meal any time.
#
# **Key Ingredients:**
# *   **Broth:** Chicken or pork stock, fresh ginger slices, green onions, a splash of soy sauce, a dash of sesame oil.
# *   **Wontons:** Wonton wrappers, ground pork, finely minced shrimp, water chestnuts (optional), soy sauce, sesame oil, white pepper, cornstarch, finely chopped ginger and green onions for the filling.
# *   **Garnish:** Fresh leafy greens like bok choy or gai lan, sliced green onions.
#
# ---
#
# ### 5. Kimchi Jjigae (Korean Kimchi Stew)
#
# **Yummy Description:** Brace yourself for a powerfully flavorful and wonderfully comforting Korean classic! Kimchi Jjigae is a bubbling, spicy, and tangy stew built around the irresistible punch of fermented kimchi. Simmered with tender pork (or other meat), silky tofu, and often vegetables, it's a hearty, warming dish that's both deeply savory and addictively spicy-sour – perfect for a chilly day or whenever you crave bold, authentic Korean flavors.
#
# **Key Ingredients:**
# *   **Main:** Well-fermented (sour) kimchi, sliced pork belly or pork shoulder (can substitute with tuna, spam, or mushrooms for vegetarian), firm or soft tofu.
# *   **Broth Base:** Anchovy broth (made with dried anchovies and dried kelp/dasima) or water/vegetable stock, gochugaru (Korean chili powder), gochujang (Korean chili paste - optional), soy sauce, minced garlic, sliced onion, green onions.
# *   **Optional Additions:** Enoki mushrooms, zucchini slices.

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config = {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [{"recipe_name":"Miso Soup","description":"A comforting and savory Japanese soup, light yet full of umami, perfect as a starter or a light meal.","ingredients":["Dashi stock","Miso paste","Tofu","Wakame seaweed","Green onions"]},
# {"recipe_name":"Tom Yum Goong","description":"A vibrant and spicy Thai hot and sour soup, bursting with aromatic flavors from lemongrass, galangal, and kaffir lime leaves, and featuring succulent shrimp.","ingredients":["Shrimp","Lemongrass","Galangal","Kaffir lime leaves","Mushrooms","Fish sauce","Lime juice","Chili paste","Cherry tomatoes","Cilantro"]},
# {"recipe_name":"Pho Bo","description":"A traditional Vietnamese beef noodle soup, known for its incredibly aromatic and complex broth, tender beef slices, and fresh herbs, making it a deeply satisfying meal.","ingredients":["Beef bones","Beef brisket","Rice noodles","Onions","Ginger","Star anise","Cinnamon sticks","Cloves","Fish sauce","Bean sprouts","Lime wedges","Basil","Cilantro","Jalapeno"]}]

# %%
recipes = response.parsed
recipes
# Out:
# [Recipe(recipe_name='Miso Soup', description='A comforting and savory Japanese soup, light yet full of umami, perfect as a starter or a light meal.', ingredients=['Dashi stock', 'Miso paste', 'Tofu', 'Wakame seaweed', 'Green onions']),
#  Recipe(recipe_name='Tom Yum Goong', description='A vibrant and spicy Thai hot and sour soup, bursting with aromatic flavors from lemongrass, galangal, and kaffir lime leaves, and featuring succulent shrimp.', ingredients=['Shrimp', 'Lemongrass', 'Galangal', 'Kaffir lime leaves', 'Mushrooms', 'Fish sauce', 'Lime juice', 'Chili paste', 'Cherry tomatoes', 'Cilantro']),
#  Recipe(recipe_name='Pho Bo', description='A traditional Vietnamese beef noodle soup, known for its incredibly aromatic and complex broth, tender beef slices, and fresh herbs, making it a deeply satisfying meal.', ingredients=['Beef bones', 'Beef brisket', 'Rice noodles', 'Onions', 'Ginger', 'Star anise', 'Cinnamon sticks', 'Cloves', 'Fish sauce', 'Bean sprouts', 'Lime wedges', 'Basil', 'Cilantro', 'Jalapeno'])]

# %%
recipes[0].description, recipes[0].recipe_name, recipes[0].ingredients
# Out:
# ('A comforting and savory Japanese soup, light yet full of umami, perfect as a starter or a light meal.',
#  'Miso Soup',
#  ['Dashi stock', 'Miso paste', 'Tofu', 'Wakame seaweed', 'Green onions'])

# %% [markdown]
# ### Simulate house pricing

# %%
from typing import Literal

class Home(BaseModel):
    price: int 
    monthly_fee: int
    living_area: float 
    number_rooms: int 
    type: Literal["apartment", "house"]
    address: str

client = genai.Client()

response= client.models.generate_content(
    model="gemini-2.5-pro",
    contents="""List 50 apartments and houses in Sweden with their monthly_fee, their price, living area, 
    number of rooms, address, type if it is apartment or house. 
    All currencies are in SEK.""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)




homes = response.parsed
homes
# Out:
# [Home(price=4500000, monthly_fee=3200, living_area=65.5, number_rooms=2, type='apartment', address='Sveavägen 78, 111 34 Stockholm'),
#  Home(price=12500000, monthly_fee=4500, living_area=180.0, number_rooms=6, type='house', address='Äppelviksvägen 22, 167 53 Bromma'),
#  Home(price=3800000, monthly_fee=4100, living_area=75.0, number_rooms=3, type='apartment', address='Linnégatan 14, 413 04 Göteborg'),
#  Home(price=6200000, monthly_fee=3800, living_area=155.0, number_rooms=5, type='house', address='Ribersborgsvägen 5, 217 53 Malmö'),
#  Home(price=2950000, monthly_fee=2800, living_area=58.5, number_rooms=2, type='apartment', address='Kungsgatan 55, 753 21 Uppsala'),
#  Home(price=5300000, monthly_fee=3200, living_area=140.0, number_rooms=5, type='house', address='Klostergatan 23, 582 23 Linköping'),
#  Home(price=1800000, monthly_fee=2100, living_area=42.0, number_rooms=1, type='apartment', address='Stora Torget 3, 722 15 Västerås'),
#  Home(price=3100000, monthly_fee=5200, living_area=95.0, number_rooms=4, type='apartment', address='Drottninggatan 10, 252 21 Helsingborg'),
#  Home(price=4500000, monthly_fee=2900, living_area=130.0, number_rooms=4, type='house', address='Tornavägen 8, 223 63 Lund'),
#  Home(price=2100000, monthly_fee=3500, living_area=68.0, number_rooms=3, type='apartment', address='Kungsgatan 15, 903 25 Umeå'),
#  Home(price=9800000, monthly_fee=5100, living_area=210.0, number_rooms=7, type='house', address='Villagatan 12, 114 32 Stockholm'),
#  Home(price=2250000, monthly_fee=2950, living_area=50.0, number_rooms=2, type='apartment', address='Vasagatan 33, 411 24 Göteborg'),
#  Home(price=1900000, monthly_fee=4300, living_area=85.0, number_rooms=3, type='apartment', address='Storgatan 50, 703 62 Örebro'),
#  Home(price=7100000, monthly_fee=4200, living_area=165.0, number_rooms=6, type='house', address='Långa raden 1, 239 40 Falsterbo'),
#  Home(price=3400000, monthly_fee=3800, living_area=72.5, number_rooms=3, type='apartment', address='S:t Eriksgatan 45, 112 34 Stockholm'),
#  Home(price=1500000, monthly_fee=1900, living_area=35.0, number_rooms=1, type='apartment', address='Studentvägen 19, 752 34 Uppsala'),
#  Home(price=4900000, monthly_fee=3100, living_area=125.0, number_rooms=4, type='house', address='Eklandagatan 5, 412 55 Göteborg'),
#  Home(price=2750000, monthly_fee=3600, living_area=78.0, number_rooms=3, type='apartment', address='Amiralsgatan 20, 211 55 Malmö'),
#  Home(price=3950000, monthly_fee=2500, living_area=110.0, number_rooms=4, type='house', address='Smultronstigen 7, 582 75 Linköping'),
#  Home(price=1250000, monthly_fee=3300, living_area=60.0, number_rooms=2, type='apartment', address='Storgatan 8, 981 31 Kiruna'),
#  Home(price=6800000, monthly_fee=4800, living_area=115.0, number_rooms=4, type='apartment', address='Hornsgatan 92, 117 26 Stockholm'),
#  Home(price=8200000, monthly_fee=4000, living_area=175.0, number_rooms=6, type='house', address='Strandvägen 15, 621 55 Visby'),
#  Home(price=3150000, monthly_fee=3900, living_area=82.0, number_rooms=3, type='apartment', address='Kungsportsavenyen 1, 411 36 Göteborg'),
#  Home(price=5600000, monthly_fee=3500, living_area=145.0, number_rooms=5, type='house', address='Limhamnsvägen 30, 217 59 Malmö'),
#  Home(price=2400000, monthly_fee=2650, living_area=55.0, number_rooms=2, type='apartment', address='Vaksalagatan 12, 753 31 Uppsala'),
#  Home(price=3200000, monthly_fee=2100, living_area=120.0, number_rooms=4, type='house', address='Pilgatan 5, 722 14 Västerås'),
#  Home(price=2900000, monthly_fee=4500, living_area=90.0, number_rooms=4, type='apartment', address='Drottninggatan 40, 223 50 Lund'),
#  Home(price=1700000, monthly_fee=3800, living_area=70.0, number_rooms=3, type='apartment', address='Rådhusesplanaden 10, 903 28 Umeå'),
#  Home(price=15500000, monthly_fee=6500, living_area=250.0, number_rooms=8, type='house', address='Djursholmsvägen 30, 182 62 Djursholm'),
#  Home(price=5200000, monthly_fee=4900, living_area=105.0, number_rooms=4, type='apartment', address='Odengatan 50, 113 51 Stockholm'),
#  Home(price=2600000, monthly_fee=3100, living_area=62.0, number_rooms=2, type='apartment', address='Andra Långgatan 25, 413 28 Göteborg'),
#  Home(price=4100000, monthly_fee=2800, living_area=135.0, number_rooms=5, type='house', address='Engelbrektsgatan 18, 702 12 Örebro'),
#  Home(price=2850000, monthly_fee=3400, living_area=76.0, number_rooms=3, type='apartment', address='Södergatan 15, 211 34 Malmö'),
#  Home(price=3600000, monthly_fee=2400, living_area=118.0, number_rooms=4, type='house', address='Stora Södergatan 22, 222 23 Lund'),
#  Home(price=1100000, monthly_fee=2500, living_area=48.0, number_rooms=2, type='apartment', address='Skolgatan 60, 903 29 Umeå'),
#  Home(price=7500000, monthly_fee=4300, living_area=150.0, number_rooms=5, type='house', address='Saltsjöpromenaden 4, 131 71 Nacka'),
#  Home(price=3900000, monthly_fee=4250, living_area=88.0, number_rooms=3, type='apartment', address='Folkungagatan 100, 116 30 Stockholm'),
#  Home(price=2150000, monthly_fee=2700, living_area=59.0, number_rooms=2, type='apartment', address='Torsgatan 2, 582 19 Linköping'),
#  Home(price=6700000, monthly_fee=3900, living_area=160.0, number_rooms=6, type='house', address='Särövägen 10, 429 42 Särö'),
#  Home(price=1950000, monthly_fee=3150, living_area=45.0, number_rooms=2, type='apartment', address='Stora Gråbrödersgatan 5, 222 22 Lund'),
#  Home(price=4400000, monthly_fee=5300, living_area=100.0, number_rooms=4, type='apartment', address='Karlavägen 80, 114 59 Stockholm'),
#  Home(price=3300000, monthly_fee=2200, living_area=128.0, number_rooms=5, type='house', address='Slottsgatan 1, 752 35 Uppsala'),
#  Home(price=2995000, monthly_fee=3700, living_area=74.0, number_rooms=3, type='apartment', address='Gibraltargatan 8, 411 32 Göteborg'),
#  Home(price=3800000, monthly_fee=2750, living_area=142.0, number_rooms=5, type='house', address='Drottninggatan 102, 252 21 Helsingborg'),
#  Home(price=1850000, monthly_fee=2900, living_area=38.0, number_rooms=1, type='apartment', address='Regementsgatan 52, 217 48 Malmö'),
#  Home(price=8900000, monthly_fee=5800, living_area=190.0, number_rooms=7, type='house', address='Lidingövägen 50, 181 59 Lidingö'),
#  Home(price=3650000, monthly_fee=4100, living_area=80.0, number_rooms=3, type='apartment', address='Sankt Pauligatan 1, 416 60 Göteborg'),
#  Home(price=2300000, monthly_fee=2200, living_area=95.0, number_rooms=4, type='house', address='Björkallén 3, 907 36 Umeå'),
#  Home(price=2500000, monthly_fee=3550, living_area=66.0, number_rooms=2, type='apartment', address='Östra Ågatan 31, 753 22 Uppsala'),
#  Home(price=19900000, monthly_fee=7500, living_area=280.0, number_rooms=8, type='house', address='Strandvägen 5, 114 51 Stockholm')]

# %%
len(homes)
# Out:
# 50

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 0   4500000         3200         65.5             2  apartment
# 1  12500000         4500        180.0             6      house
# 2   3800000         4100         75.0             3  apartment
# 3   6200000         3800        155.0             5      house
# 4   2950000         2800         58.5             2  apartment
#
#                             address
# 0    Sveavägen 78, 111 34 Stockholm
# 1  Äppelviksvägen 22, 167 53 Bromma
# 2    Linnégatan 14, 413 04 Göteborg
# 3  Ribersborgsvägen 5, 217 53 Malmö
# 4     Kungsgatan 55, 753 21 Uppsala

# %%
df.query("price < 3_000_000")
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 4   2950000         2800         58.5             2  apartment
# 6   1800000         2100         42.0             1  apartment
# 9   2100000         3500         68.0             3  apartment
# 11  2250000         2950         50.0             2  apartment
# 12  1900000         4300         85.0             3  apartment
# 15  1500000         1900         35.0             1  apartment
# 17  2750000         3600         78.0             3  apartment
# 19  1250000         3300         60.0             2  apartment
# 24  2400000         2650         55.0             2  apartment
# 26  2900000         4500         90.0             4  apartment
# 27  1700000         3800         70.0             3  apartment
# 30  2600000         3100         62.0             2  apartment
# 32  2850000         3400         76.0             3  apartment
# 34  1100000         2500         48.0             2  apartment
# 37  2150000         2700         59.0             2  apartment
# 39  1950000         3150         45.0             2  apartment
# 42  2995000         3700         74.0             3  apartment
# 44  1850000         2900         38.0             1  apartment
# 47  2300000         2200         95.0             4      house
# 48  2500000         3550         66.0             2  apartment
#
#                                  address
# 4          Kungsgatan 55, 753 21 Uppsala
# 6        Stora Torget 3, 722 15 Västerås
# 9             Kungsgatan 15, 903 25 Umeå
# 11         Vasagatan 33, 411 24 Göteborg
# 12           Storgatan 50, 703 62 Örebro
# 15       Studentvägen 19, 752 34 Uppsala
# 17         Amiralsgatan 20, 211 55 Malmö
# 19            Storgatan 8, 981 31 Kiruna
# 24       Vaksalagatan 12, 753 31 Uppsala
# 26        Drottninggatan 40, 223 50 Lund
# 27      Rådhusesplanaden 10, 903 28 Umeå
# 30   Andra Långgatan 25, 413 28 Göteborg
# 32           Södergatan 15, 211 34 Malmö
# 34             Skolgatan 60, 903 29 Umeå
# 37         Torsgatan 2, 582 19 Linköping
# 39  Stora Gråbrödersgatan 5, 222 22 Lund
# 42     Gibraltargatan 8, 411 32 Göteborg
# 44       Regementsgatan 52, 217 48 Malmö
# 47             Björkallén 3, 907 36 Umeå
# 48       Östra Ågatan 31, 753 22 Uppsala
