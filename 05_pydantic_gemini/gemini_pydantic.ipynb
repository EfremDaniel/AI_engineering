# %%
from dotenv import load_dotenv
from google import genai
import os

load_dotenv()
# Out:
# True

# %%
client = genai.Client(api_key=os.getenv("05_GEMINI_PYDANTIC"))

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI learns patterns from data to make smart decisions.

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""You are a helpful assistant. I need you to create a JSON object representing a library. 
    The library's name should be 'Coolu Libraru' and have the fields name and books that contains a list of book. 
    Each book should have a 'title', 'author', and 'year' field. Make sure the output is a single, valid JSON object. Give me 10 books. 
    Remove ```json and ``` """,
)

response.text
# Out:
# '{\n  "name": "Coolu Libraru",\n  "books": [\n    {\n      "title": "The Silent Planet",\n      "author": "C.S. Lewis",\n      "year": 1938\n    },\n    {\n      "title": "Dune",\n      "author": "Frank Herbert",\n      "year": 1965\n    },\n    {\n      "title": "Pride and Prejudice",\n      "author": "Jane Austen",\n      "year": 1813\n    },\n    {\n      "title": "1984",\n      "author": "George Orwell",\n      "year": 1949\n    },\n    {\n      "title": "To Kill a Mockingbird",\n      "author": "Harper Lee",\n      "year": 1960\n    },\n    {\n      "title": "The Hitchhiker\'s Guide to the Galaxy",\n      "author": "Douglas Adams",\n      "year": 1979\n    },\n    {\n      "title": "Foundation",\n      "author": "Isaac Asimov",\n      "year": 1951\n    },\n    {\n      "title": "Brave New World",\n      "author": "Aldous Huxley",\n      "year": 1932\n    },\n    {\n      "title": "The Great Gatsby",\n      "author": "F. Scott Fitzgerald",\n      "year": 1925\n    },\n    {\n      "title": "Moby Dick",\n      "author": "Herman Melville",\n      "year": 1851\n    }\n  ]\n}'

# %%
print(response.text)
# Out:
# {
#   "name": "Coolu Libraru",
#   "books": [
#     {
#       "title": "The Silent Planet",
#       "author": "C.S. Lewis",
#       "year": 1938
#     },
#     {
#       "title": "Dune",
#       "author": "Frank Herbert",
#       "year": 1965
#     },
#     {
#       "title": "Pride and Prejudice",
#       "author": "Jane Austen",
#       "year": 1813
#     },
#     {
#       "title": "1984",
#       "author": "George Orwell",
#       "year": 1949
#     },
#     {
#       "title": "To Kill a Mockingbird",
#       "author": "Harper Lee",
#       "year": 1960
#     },
#     {
#       "title": "The Hitchhiker's Guide to the Galaxy",
#       "author": "Douglas Adams",
#       "year": 1979
#     },
#     {
#       "title": "Foundation",
#       "author": "Isaac Asimov",
#       "year": 1951
#     },
#     {
#       "title": "Brave New World",
#       "author": "Aldous Huxley",
#       "year": 1932
#     },
#     {
#       "title": "The Great Gatsby",
#       "author": "F. Scott Fitzgerald",
#       "year": 1925
#     },
#     {
#       "title": "Moby Dick",
#       "author": "Herman Melville",
#       "year": 1851
#     }
#   ]
# }

# %%
from pydantic import BaseModel, Field 
from typing import List
from datetime import datetime

class Book(BaseModel):
    title: str 
    author: str 
    year: int = Field(gt = 1000, lt = datetime.now().year)

class Library(BaseModel):
    name: str 
    books: List[Book]


library = Library.model_validate_json(response.text)
library
# Out:
# Library(name='Coolu Libraru', books=[Book(title='The Silent Planet', author='C.S. Lewis', year=1938), Book(title='Dune', author='Frank Herbert', year=1965), Book(title='Pride and Prejudice', author='Jane Austen', year=1813), Book(title='1984', author='George Orwell', year=1949), Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960), Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979), Book(title='Foundation', author='Isaac Asimov', year=1951), Book(title='Brave New World', author='Aldous Huxley', year=1932), Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925), Book(title='Moby Dick', author='Herman Melville', year=1851)])

# %%
library.__dict__
# Out:
# {'name': 'Coolu Libraru',
#  'books': [Book(title='The Silent Planet', author='C.S. Lewis', year=1938),
#   Book(title='Dune', author='Frank Herbert', year=1965),
#   Book(title='Pride and Prejudice', author='Jane Austen', year=1813),
#   Book(title='1984', author='George Orwell', year=1949),
#   Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960),
#   Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979),
#   Book(title='Foundation', author='Isaac Asimov', year=1951),
#   Book(title='Brave New World', author='Aldous Huxley', year=1932),
#   Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925),
#   Book(title='Moby Dick', author='Herman Melville', year=1851)]}

# %%
type(library)
# Out:
# __main__.Library

# %%
isinstance(library, BaseModel)
# Out:
# True

# %%
library.name
# Out:
# 'Coolu Libraru'

# %%
library.books
# Out:
# [Book(title='The Silent Planet', author='C.S. Lewis', year=1938),
#  Book(title='Dune', author='Frank Herbert', year=1965),
#  Book(title='Pride and Prejudice', author='Jane Austen', year=1813),
#  Book(title='1984', author='George Orwell', year=1949),
#  Book(title='To Kill a Mockingbird', author='Harper Lee', year=1960),
#  Book(title="The Hitchhiker's Guide to the Galaxy", author='Douglas Adams', year=1979),
#  Book(title='Foundation', author='Isaac Asimov', year=1951),
#  Book(title='Brave New World', author='Aldous Huxley', year=1932),
#  Book(title='The Great Gatsby', author='F. Scott Fitzgerald', year=1925),
#  Book(title='Moby Dick', author='Herman Melville', year=1851)]

# %%
titles = [book.title for book in library.books]
titles
# Out:
# ['The Silent Planet',
#  'Dune',
#  'Pride and Prejudice',
#  '1984',
#  'To Kill a Mockingbird',
#  "The Hitchhiker's Guide to the Galaxy",
#  'Foundation',
#  'Brave New World',
#  'The Great Gatsby',
#  'Moby Dick']

# %%
newer_books = [(book.title, book.year) for book in library.books]
newer_books
# Out:
# [('The Silent Planet', 1938),
#  ('Dune', 1965),
#  ('Pride and Prejudice', 1813),
#  ('1984', 1949),
#  ('To Kill a Mockingbird', 1960),
#  ("The Hitchhiker's Guide to the Galaxy", 1979),
#  ('Foundation', 1951),
#  ('Brave New World', 1932),
#  ('The Great Gatsby', 1925),
#  ('Moby Dick', 1851)]

# %%
library.model_dump()
# Out:
# {'name': 'Coolu Libraru',
#  'books': [{'title': 'The Silent Planet',
#    'author': 'C.S. Lewis',
#    'year': 1938},
#   {'title': 'Dune', 'author': 'Frank Herbert', 'year': 1965},
#   {'title': 'Pride and Prejudice', 'author': 'Jane Austen', 'year': 1813},
#   {'title': '1984', 'author': 'George Orwell', 'year': 1949},
#   {'title': 'To Kill a Mockingbird', 'author': 'Harper Lee', 'year': 1960},
#   {'title': "The Hitchhiker's Guide to the Galaxy",
#    'author': 'Douglas Adams',
#    'year': 1979},
#   {'title': 'Foundation', 'author': 'Isaac Asimov', 'year': 1951},
#   {'title': 'Brave New World', 'author': 'Aldous Huxley', 'year': 1932},
#   {'title': 'The Great Gatsby', 'author': 'F. Scott Fitzgerald', 'year': 1925},
#   {'title': 'Moby Dick', 'author': 'Herman Melville', 'year': 1851}]}

# %%
with open("library.json", "w") as json_file:
    json_file.write(library.model_dump_json())

# %%
import pandas as pd

titles = [book.title for book in library.books]
years = [book.year for book in library.books]
authors = [book.author for book in library.books]

pd.DataFrame({"Title": titles, "Year": years, "Author": authors})
# Out:
#                                   Title  Year               Author
# 0                     The Silent Planet  1938           C.S. Lewis
# 1                                  Dune  1965        Frank Herbert
# 2                   Pride and Prejudice  1813          Jane Austen
# 3                                  1984  1949        George Orwell
# 4                 To Kill a Mockingbird  1960           Harper Lee
# 5  The Hitchhiker's Guide to the Galaxy  1979        Douglas Adams
# 6                            Foundation  1951         Isaac Asimov
# 7                       Brave New World  1932        Aldous Huxley
# 8                      The Great Gatsby  1925  F. Scott Fitzgerald
# 9                             Moby Dick  1851      Herman Melville
